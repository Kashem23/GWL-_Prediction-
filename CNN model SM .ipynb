# %%
import numpy as np
import pandas as pd
from keras.layers import Dense, LSTM, Conv1D, Flatten, MaxPooling1D, Dropout
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from IPython.core.pylabtools import figsize

# %%
data = pd.read_excel("sm.xls")

# %%
train_size = int(len(data)*0.7)
train_dataset, test_dataset = data.iloc[:train_size], data.iloc[train_size:]

# %%
# Split train data to X and y
X_train = train_dataset.drop('Eto', axis = 1)
y_train = train_dataset.loc[:,['Eto']]

# Split test data to X and y
X_test = test_dataset.drop('Eto', axis = 1)
y_test = test_dataset.loc[:,['Eto']]

# %%
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train_series = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_series = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model= Sequential()
model.add(Conv1D(128,kernel_size=3,input_shape=(5,1)))
model.add(MaxPooling1D(pool_size=3))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 3, 128)            512
#
#  max_pooling1d (MaxPooling1D  (None, 1, 128)           0
#  )
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 641
# Trainable params: 641
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size=32,epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 2s 10ms/step - loss: 20.6977 - val_loss: 7.0857
# Epoch 2/30
# 56/56 [==============================] - 0s 4ms/step - loss: 5.3256 - val_loss: 2.3258
# Epoch 3/30
# 56/56 [==============================] - 0s 4ms/step - loss: 3.5270 - val_loss: 2.1483
# Epoch 4/30
# 56/56 [==============================] - 0s 4ms/step - loss: 3.3016 - val_loss: 2.0475
# Epoch 5/30
# 56/56 [==============================] - 0s 4ms/step - loss: 3.0764 - val_loss: 1.8153
# Epoch 6/30
# 56/56 [==============================] - 0s 4ms/step - loss: 2.8259 - val_loss: 1.6204
# Epoch 7/30
# 56/56 [==============================] - 0s 4ms/step - loss: 2.5590 - val_loss: 1.4315
# Epoch 8/30
# 56/56 [==============================] - 0s 4ms/step - loss: 2.2713 - val_loss: 1.2821
# Epoch 9/30
# 56/56 [==============================] - 0s 4ms/step - loss: 1.9787 - val_loss: 1.0683
# Epoch 10/30
# 56/56 [==============================] - 0s 4ms/step - loss: 1.6803 - val_loss: 0.7957
# Epoch 11/30
# 56/56 [==============================] - 0s 4ms/step - loss: 1.4035 - val_loss: 0.6487
# Epoch 12/30
# 56/56 [==============================] - 0s 4ms/step - loss: 1.1408 - val_loss: 0.5383
# Epoch 13/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.9229 - val_loss: 0.3923
# Epoch 14/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.7404 - val_loss: 0.2539
# Epoch 15/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.5978 - val_loss: 0.1923
# Epoch 16/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4952 - val_loss: 0.1584
# Epoch 17/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4205 - val_loss: 0.1221
# Epoch 18/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3667 - val_loss: 0.1063
# Epoch 19/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3269 - val_loss: 0.0965
# Epoch 20/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2988 - val_loss: 0.0927
# Epoch 21/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2739 - val_loss: 0.0843
# Epoch 22/30
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2567 - val_loss: 0.0816
# Epoch 23/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2388 - val_loss: 0.0780
# Epoch 24/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2257 - val_loss: 0.0761
# Epoch 25/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2154 - val_loss: 0.0745
# Epoch 26/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2062 - val_loss: 0.0730
# Epoch 27/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2025 - val_loss: 0.0733
# Epoch 28/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1923 - val_loss: 0.0748
# Epoch 29/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1857 - val_loss: 0.0723
# Epoch 30/30
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1811 - val_loss: 0.0690

# %%
ypredtrain = model.predict(X_train)
print(model.evaluate(X_train, y_train))
print("MSE: %.4f" % mean_squared_error(y_train, ypredtrain))
# Out:
# 56/56 [==============================] - 0s 2ms/step
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1770
# 0.17695842683315277
# MSE: 0.1770

# %%
# Evaluation metrices RMSE,MSE,  MAE and R square
print("Train data RMSE: ", math.sqrt(mean_squared_error(y_train,ypredtrain)))
print("Train data MSE: ", mean_squared_error(y_train,ypredtrain))
print("Train data MAE: ", mean_absolute_error(y_train,ypredtrain))
print("Train data R2 score:", r2_score(y_train , ypredtrain ))
# Out:
# Train data RMSE:  0.4206642911273287
# Train data MSE:  0.176958445829658
# Train data MAE:  0.24886220380405663
# Train data R2 score: 0.9507697841499355

# %%
## convert your array into a dataframe
df_pred = pd.DataFrame (ypredtrain)
df_pred.to_excel('Pred_CNN_train__SM.xlsx')

# %%
ypredtest = model.predict(X_test)
print(model.evaluate(X_test, y_test))
print("MSE: %.4f" % mean_squared_error(y_test, ypredtest))
# Out:
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0690
# 0.0690285786986351
# MSE: 0.0690

# %%
# Evaluation metrices RMSE, MSE, MAE and R square
print("Test data RMSE: ", math.sqrt(mean_squared_error(y_test,ypredtest)))
print("Test data MSE: ", mean_squared_error(y_test,ypredtest))
print("Test data MAE: ", mean_absolute_error(y_test,ypredtest))
print("Test data R2 score:", r2_score(y_test , ypredtest ))
# Out:
# Test data RMSE:  0.262732927223314
# Test data MSE:  0.0690285910473312
# Test data MAE:  0.2069895984232426
# Test data R2 score: 0.9680665382733127

# %%
## convert your array into a dataframe
df_pred = pd.DataFrame (ypredtest)
df_pred.to_excel('Pred_CNN_test__SM.xlsx')
